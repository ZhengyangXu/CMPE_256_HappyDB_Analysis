# %%
 # %matplotlib inline
import re
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
##from wordcloud import WordCloud

# %%
hm_data = pd.read_csv('cleaned_hm.csv')
hm_data.head()
# Out:
#     hmid   wid reflection_period  \
# 0  27673  2053               24h
# 1  27674     2               24h
# 2  27675  1936               24h
# 3  27676   206               24h
# 4  27677  6227               24h
#
#                                          original_hm  \
# 0  I went on a successful date with someone I fel...
# 1  I was happy when my son got 90% marks in his e...
# 2       I went to the gym this morning and did yoga.
# 3  We had a serious talk with some friends of our...
# 4  I went with grandchildren to butterfly display...
#
#                                           cleaned_hm  modified  num_sentence  \
# 0  I went on a successful date with someone I fel...      True             1
# 1  I was happy when my son got 90% marks in his e...      True             1
# 2       I went to the gym this morning and did yoga.      True             1
# 3  We had a serious talk with some friends of our...      True             2
# 4  I went with grandchildren to butterfly display...      True             1
#
#   ground_truth_category predicted_category
# 0                   NaN          affection
# 1                   NaN          affection
# 2                   NaN           exercise
# 3               bonding            bonding
# 4                   NaN          affection

# %%
hm_data.count()
# Out:
# hmid                     100535
# wid                      100535
# reflection_period        100535
# original_hm              100535
# cleaned_hm               100535
# modified                 100535
# num_sentence             100535
# ground_truth_category     14125
# predicted_category       100535
# dtype: int64

# %%
hm_data.predicted_category.unique()
# Out:
# array(['affection', 'exercise', 'bonding', 'leisure', 'achievement',
#        'enjoy_the_moment', 'nature'], dtype=object)

# %%
hm_data.loc[hm_data["reflection_period"]=='3m'].head()
# Out:
#         hmid   wid reflection_period  \
# 30455  58297   888                3m
# 30456  58298   129                3m
# 30457  58299  1354                3m
# 30458  58300   384                3m
# 30459  58301  1111                3m
#
#                                              original_hm  \
# 30455            nowing im going to travel to china soon
# 30456                        I ate a really good dinner.
# 30457    I went to a Lehigh Valley phantoms hockey game.
# 30458                            I saw the woman I love.
# 30459  the babyset i ordered finally came and i set i...
#
#                                               cleaned_hm  modified  \
# 30455            nowing im going to travel to china soon      True
# 30456                        I ate a really good dinner.      True
# 30457    I went to a Lehigh Valley phantoms hockey game.      True
# 30458                            I saw the woman I love.      True
# 30459  the baby set i ordered finally came and i set ...     False
#
#        num_sentence ground_truth_category predicted_category
# 30455             1               leisure            leisure
# 30456             1                   NaN   enjoy_the_moment
# 30457             1                   NaN            leisure
# 30458             1                   NaN          affection
# 30459             1                   NaN        achievement

# %%
df_hm = hm_data[hm_data['cleaned_hm'].notnull()]
len_count = df_hm['cleaned_hm'].apply(lambda x: len(x.split()))
len_count.describe()
# Out:
# count    100535.000000
# mean         18.298503
# std          21.474146
# min           2.000000
# 25%           9.000000
# 50%          14.000000
# 75%          21.000000
# max        1179.000000
# Name: cleaned_hm, dtype: float64

# %%
df_hm[df_hm['cleaned_hm'].apply(lambda x: len(x.split()))==2].head()
# Out:
#         hmid    wid reflection_period     original_hm      cleaned_hm  \
# 1100   28775    634               24h  Shooting guns.  Shooting guns.
# 4903   32612   7012               24h       My kids.        My kids.
# 7646   35375   2082               24h      dude, weed      dude, weed
# 12496  40246    755               24h  watching ncis.  watching ncis.
# 14868  42633  10831               24h  Donated blood.  Donated blood.
#
#        modified  num_sentence ground_truth_category predicted_category
# 1100       True             1                   NaN            leisure
# 4903       True             1                   NaN          affection
# 7646       True             1                   NaN   enjoy_the_moment
# 12496      True             1                   NaN            leisure
# 14868      True             1                   NaN        achievement

# %%
length_order = ["0-4", "5-9", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", \
                "40-44", "45-49", ">=50"]
length_category = len_count.apply(lambda x: length_order[min(10, int(x/5))])
length_counts = pd.DataFrame(length_category.value_counts()).reset_index()
length_counts.columns = ['word numbers', '# of moments']

sns.barplot(x='word numbers', y='# of moments', data=length_counts, order=length_order)

# %%
#text = ' '.join(df_hm['cleaned_hm'].tolist())
#text = text.lower()
#wordcloud = WordCloud(background_color="white", height=2700, width=3600).generate(text)
#plt.figure( figsize=(14,8) )
#plt.imshow(wordcloud.recolor(colormap=plt.get_cmap('Set2')), interpolation='bilinear')
#plt.axis("off")

# %%
seasons = ['Spring', 'Summer', 'Fall', 'Winter']

# Check each moment, and increase the count for the mentioned season
season_dic = dict((x,0) for x in seasons)
tokens_hm = df_hm['cleaned_hm'].apply(lambda x: x.split())
for _, value in tokens_hm.iteritems():
    for word in value:
        if word in seasons:
            season_dic[word] += 1
            
season_dic
# Out:
# {'Fall': 6, 'Spring': 81, 'Summer': 27, 'Winter': 6}

# %%
# Read the happyDB sample file
with open('happydb.txt', 'w') as ofile:
    len = int(df_hm.shape[0] / 8)
    for i in range(0, len - 1):
        ofile.write(df_hm['cleaned_hm'].iloc[i] + '\n')
        
print("Happy moments are retrieved!")
# Out:
# Happy moments are retrieved!

# %%
df1 = pd.read_csv('demographic.csv')

# %%
df1.count()
# Out:
# wid           10844
# age           10809
# country       10771
# gender        10812
# marital       10787
# parenthood    10813
# dtype: int64

# %%
# to combine two datasets we can use merge or append
hm_new = pd.merge(hm_data , df1)

# %%
hm_new.head()
# Out:
#     hmid   wid reflection_period  \
# 0  27673  2053               24h
# 1  27873  2053               24h
# 2  28073  2053               24h
# 3  33522  2053               24h
# 4  34522  2053               24h
#
#                                          original_hm  \
# 0  I went on a successful date with someone I fel...
# 1  I played a new game that was fun and got to en...
# 2  I listened to some music and heard an entire a...
# 3                 Went to see a movie with my friend
# 4               Played guitar, learning a song on it
#
#                                           cleaned_hm  modified  num_sentence  \
# 0  I went on a successful date with someone I fel...      True             1
# 1  I played a new game that was fun and got to en...      True             1
# 2  I listened to some music and heard an entire a...      True             1
# 3                 Went to see a movie with my friend      True             1
# 4               Played guitar, learning a song on it      True             1
#
#   ground_truth_category predicted_category age country gender marital  \
# 0                   NaN          affection  35     USA      m  single
# 1                   NaN            leisure  35     USA      m  single
# 2                   NaN            leisure  35     USA      m  single
# 3                   NaN            bonding  35     USA      m  single
# 4                   NaN            leisure  35     USA      m  single
#
#   parenthood
# 0          n
# 1          n
# 2          n
# 3          n
# 4          n

# %%
hm_new.count()
# Out:
# hmid                     100535
# wid                      100535
# reflection_period        100535
# original_hm              100535
# cleaned_hm               100535
# modified                 100535
# num_sentence             100535
# ground_truth_category     14125
# predicted_category       100535
# age                      100442
# country                  100332
# gender                   100456
# marital                  100378
# parenthood               100457
# dtype: int64

# %%
hm_data.count()
# Out:
# hmid                     100535
# wid                      100535
# reflection_period        100535
# original_hm              100535
# cleaned_hm               100535
# modified                 100535
# num_sentence             100535
# ground_truth_category     14125
# predicted_category       100535
# dtype: int64

# %%
hm_data
# Out:
#           hmid    wid reflection_period  \
# 0        27673   2053               24h
# 1        27674      2               24h
# 2        27675   1936               24h
# 3        27676    206               24h
# 4        27677   6227               24h
# 5        27678     45               24h
# 6        27679    195               24h
# 7        27680    740               24h
# 8        27681      3               24h
# 9        27682   4833               24h
# 10       27683   7334               24h
# 11       27684     78               24h
# 12       27685     21               24h
# 13       27686      8               24h
# 14       27687    586               24h
# 15       27688    489               24h
# 16       27689    976               24h
# 17       27690   3972               24h
# 18       27691     14               24h
# 19       27692   1230               24h
# 20       27693   9950               24h
# 21       27694   4862               24h
# 22       27695   4891               24h
# 23       27696    737               24h
# 24       27697    498               24h
# 25       27698   2124               24h
# 26       27699    156               24h
# 27       27700   1783               24h
# 28       27701   3382               24h
# 29       27702     54               24h
# ...        ...    ...               ...
# 100505  128737   1161               24h
# 100506  128738   2780               24h
# 100507  128739   2545               24h
# 100508  128740  10983               24h
# 100509  128741   3948               24h
# 100510  128742    525               24h
# 100511  128743  13605               24h
# 100512  128744   5180               24h
# 100513  128745   1234               24h
# 100514  128746    248               24h
# 100515  128747   2974               24h
# 100516  128748   8880               24h
# 100517  128749   2616               24h
# 100518  128750    323               24h
# 100519  128751  11402               24h
# 100520  128752    301               24h
# 100521  128753    597               24h
# 100522  128754    105               24h
# 100523  128755     22               24h
# 100524  128756    412               24h
# 100525  128757   1767               24h
# 100526  128758   4428               24h
# 100527  128759  11050               24h
# 100528  128760      5               24h
# 100529  128761   4298               24h
# 100530  128762    112               24h
# 100531  128763    714               24h
# 100532  128764   3934               24h
# 100533  128765   1629               24h
# 100534  128766    141               24h
#
#                                               original_hm  \
# 0       I went on a successful date with someone I fel...
# 1       I was happy when my son got 90% marks in his e...
# 2            I went to the gym this morning and did yoga.
# 3       We had a serious talk with some friends of our...
# 4       I went with grandchildren to butterfly display...
# 5                                 I meditated last night.
# 6       I made a new recipe for peasant bread, and it ...
# 7       I got gift from my elder brother which was rea...
# 8                 YESTERDAY MY MOMS BIRTHDAY SO I ENJOYED
# 9       Watching cupcake wars with my three teen children
# 10      I came in 3rd place in my Call of Duty video g...
# 11      I completed my 5 miles run without break. It m...
# 12             went to movies with my friends it was fun
# 13      I was shorting Gold and made $200 from the trade.
# 14      Hearing Songs It can be nearly impossible to g...
# 15      My son performed very well for a test preparat...
# 16       I helped my neighbour to fix their car damages.
# 17      Managed to get the final trophy in a game I wa...
# 18      A hot kiss with my girl friend last night made...
# 19      My new BCAAs came in the mail. Yay! Strawberry...
# 20                                        Got A in class.
# 21      My sister called me from abroad this morning a...
# 22      The cake I made today came out amazing. It tas...
# 23      There are two types of people in the world: th...
# 24      My grandmother start to walk from the bed afte...
# 25           i was able to hit a top spin serve in tennis
# 26      I napped with my husband on the bed this after...
# 27      My co-woker started playing a Carley Rae Jepse...
# 28      My son woke me up to a fantastic breakfast of ...
# 29      After a long time my brother gave a suprise vi...
# ...                                                   ...
# 100505                                DRY DAY CELEBRATION
# 100506                         My bills were paid on time
# 100507  I watched my favorite gamer on Twitch.tv and h...
# 100508  I was able to accomplish one of my goals at wo...
# 100509  I heard a song I really like on the radio this...
# 100510    A friend called just to see how i'd been doing.
# 100511  Last night while attending my grandmother's wa...
# 100512  My friend came to my home and he give some gif...
# 100513  I went shopping for Father's Day dinner on Sun...
# 100514  I woke up in the middle of the night and reali...
# 100515            I had pizza for dinner and it was great
# 100516  My husband called me just to tell me he loved me.
# 100517  I was able to weed my entire garden and plant ...
# 100518  A coworker praised the job I did on a recent p...
# 100519                                     Fixed my car.
# 100520    I had a little time to myself in the afternoon.
# 100521     I worked out, which always makes me feel good.
# 100522  Finally got to watch the new Resident Evil movie.
# 100523  I made plans to go to a new restaurant with th...
# 100524  Those rare, perfectly timed naps that leave yo...
# 100525  I got to talk to an old friend and reminisce o...
# 100526  Yesterday my relations came to my house. That ...
# 100527  I am fond of seeing cricket match. Yesterday t...
# 100528  My daughter made a very funny sound when I was...
# 100529                     I spent time with my daughter.
# 100530  My husband announced he is getting a decent bo...
# 100531                       Had a can of Pepsi to drink.
# 100532            Cuddling with my girlfriend last night.
# 100533  I had a great meeting yesterday at work with m...
# 100534                  I had a great workout last night.
#
#                                                cleaned_hm  modified  \
# 0       I went on a successful date with someone I fel...      True
# 1       I was happy when my son got 90% marks in his e...      True
# 2            I went to the gym this morning and did yoga.      True
# 3       We had a serious talk with some friends of our...      True
# 4       I went with grandchildren to butterfly display...      True
# 5                                 I meditated last night.      True
# 6       I made a new recipe for peasant bread, and it ...      True
# 7       I got gift from my elder brother which was rea...      True
# 8                 YESTERDAY MY MOMS BIRTHDAY SO I ENJOYED      True
# 9       Watching cupcake wars with my three teen children      True
# 10      I came in 3rd place in my Call of Duty video g...      True
# 11      I completed my 5 miles run without break. It m...      True
# 12             went to movies with my friends it was fun       True
# 13      I was shorting Gold and made $200 from the trade.      True
# 14      Hearing Songs It can be nearly impossible to g...     False
# 15      My son performed very well for a test preparat...      True
# 16       I helped my neighbour to fix their car damages.       True
# 17      Managed to get the final trophy in a game I wa...      True
# 18      A hot kiss with my girl friend last night made...      True
# 19      My new BCAAs came in the mail. Yay! Strawberry...      True
# 20                                        Got A in class.      True
# 21      My sister called me from abroad this morning a...      True
# 22      The cake I made today came out amazing. It tas...      True
# 23      There are two types of people in the world: th...     False
# 24      My grandmother start to walk from the bed afte...      True
# 25           i was able to hit a top spin serve in tennis      True
# 26      I napped with my husband on the bed this after...      True
# 27      My co-woker started playing a Carley Rae Jepse...      True
# 28      My son woke me up to a fantastic breakfast of ...      True
# 29      After a long time my brother gave a suprise vi...      True
# ...                                                   ...       ...
# 100505                                DRY DAY CELEBRATION      True
# 100506                         My bills were paid on time      True
# 100507  I watched my favorite gamer on Twitch.tv and h...      True
# 100508  I was able to accomplish one of my goals at wo...      True
# 100509  I heard a song I really like on the radio this...      True
# 100510    A friend called just to see how i'd been doing.      True
# 100511  Last night while attending my grandmother's wa...      True
# 100512  My friend came to my home and he give some gif...      True
# 100513  I went shopping for Father's Day dinner on Sun...      True
# 100514  I woke up in the middle of the night and reali...      True
# 100515            I had pizza for dinner and it was great      True
# 100516  My husband called me just to tell me he loved me.      True
# 100517  I was able to weed my entire garden and plant ...      True
# 100518  A coworker praised the job I did on a recent p...      True
# 100519                                     Fixed my car.       True
# 100520    I had a little time to myself in the afternoon.      True
# 100521     I worked out, which always makes me feel good.      True
# 100522  Finally got to watch the new Resident Evil movie.      True
# 100523  I made plans to go to a new restaurant with th...      True
# 100524  Those rare, perfectly timed naps that leave yo...      True
# 100525  I got to talk to an old friend and reminisce o...      True
# 100526  Yesterday my relations came to my house. That ...      True
# 100527  I am fond of seeing cricket match. Yesterday t...      True
# 100528  My daughter made a very funny sound when I was...      True
# 100529                     I spent time with my daughter.      True
# 100530  My husband announced he is getting a decent bo...      True
# 100531                       Had a can of Pepsi to drink.      True
# 100532            Cuddling with my girlfriend last night.      True
# 100533  I had a great meeting yesterday at work with m...      True
# 100534                  I had a great workout last night.      True
#
#         num_sentence ground_truth_category predicted_category
# 0                  1                   NaN          affection
# 1                  1                   NaN          affection
# 2                  1                   NaN           exercise
# 3                  2               bonding            bonding
# 4                  1                   NaN          affection
# 5                  1               leisure            leisure
# 6                  1                   NaN        achievement
# 7                  1                   NaN          affection
# 8                  1                   NaN   enjoy_the_moment
# 9                  1                   NaN          affection
# 10                 1                   NaN            leisure
# 11                 2                   NaN           exercise
# 12                 1                   NaN            bonding
# 13                 1                   NaN        achievement
# 14                 2                   NaN   enjoy_the_moment
# 15                 1                   NaN          affection
# 16                 1                   NaN            bonding
# 17                 1                   NaN        achievement
# 18                 1                   NaN            bonding
# 19                 3                   NaN          affection
# 20                 1                   NaN        achievement
# 21                 2                   NaN          affection
# 22                 2                   NaN        achievement
# 23                 2                   NaN   enjoy_the_moment
# 24                 1             affection          affection
# 25                 1                   NaN        achievement
# 26                 1                   NaN          affection
# 27                 1                   NaN            leisure
# 28                 1                   NaN          affection
# 29                 1                   NaN          affection
# ...              ...                   ...                ...
# 100505             1                   NaN        achievement
# 100506             1                   NaN        achievement
# 100507             1                   NaN            leisure
# 100508             1                   NaN        achievement
# 100509             1                   NaN   enjoy_the_moment
# 100510             1                   NaN            bonding
# 100511             1                   NaN            bonding
# 100512             1                   NaN            bonding
# 100513             1                   NaN          affection
# 100514             1      enjoy_the_moment   enjoy_the_moment
# 100515             1                   NaN   enjoy_the_moment
# 100516             1                   NaN          affection
# 100517             1                   NaN             nature
# 100518             1                   NaN        achievement
# 100519             1                   NaN        achievement
# 100520             1                   NaN   enjoy_the_moment
# 100521             1                   NaN   enjoy_the_moment
# 100522             1                   NaN            leisure
# 100523             1                   NaN            bonding
# 100524             3                   NaN        achievement
# 100525             1                   NaN            bonding
# 100526             2             affection          affection
# 100527             6                   NaN   enjoy_the_moment
# 100528             1                   NaN          affection
# 100529             1                   NaN          affection
# 100530             1                   NaN          affection
# 100531             1                   NaN   enjoy_the_moment
# 100532             1             affection          affection
# 100533             1                   NaN            bonding
# 100534             1                   NaN           exercise
#
# [100535 rows x 9 columns]

# %%
df1
# Out:
#          wid   age country gender    marital parenthood
# 0          1  37.0     USA      m    married          y
# 1          2  29.0     IND      m    married          y
# 2          3    25     IND      m     single          n
# 3          4    32     USA      m    married          y
# 4          5    29     USA      m    married          y
# 5          6    35     IND      m    married          y
# 6          7    34     USA      m    married          y
# 7          8    29     VNM      m     single          n
# 8          9    61     USA      f    married          y
# 9         10    27     USA      m     single          n
# 10        11  45.0     USA      m   divorced          n
# 11        12    25     USA      f     single          n
# 12        13  45.0     IND      m    married          y
# 13        14  25.0     IND      m    married          y
# 14        15    27     USA      m    married          y
# 15        16  35.0     USA      m     single          n
# 16        17  30.0     USA      m     single          n
# 17        18    30     USA      m     single          n
# 18        19    29     USA      m    married          n
# 19        20    40     USA      m    married          y
# 20        21  29.0     IND      m     single          y
# 21        22    32     USA      m     single          n
# 22        23    27     IND      m     single          n
# 23        24    35     IND      f     single          n
# 24        25  32.0     IND      m    married          y
# 25        26  31.0     IND      f    married          y
# 26        27    28     USA      m    married          y
# 27        28  36.0     USA      m    married          y
# 28        29    44     USA      m     single          n
# 29        30  37.0     USA      m    married          y
# ...      ...   ...     ...    ...        ...        ...
# 10814  13797  26.0     USA      f     single          n
# 10815  13798    42     USA      m    married          y
# 10816  13799  20.0     USA      m     single          n
# 10817  13800    19     USA      f     single          n
# 10818  13803    22     ISL      m     single          n
# 10819  13804    46     USA      m     single          n
# 10820  13805    30     UKR      m     single          n
# 10821  13808  42.0     USA      f     single          y
# 10822  13810    47     USA      m    married          n
# 10823  13811  24.0     USA      f     single          n
# 10824  13814    34     USA      f    married          y
# 10825  13815    32     USA      f    married          y
# 10826  13816  35.0     USA      m     single          n
# 10827  13817    36     USA      m  separated          y
# 10828  13819  28.0     USA      m     single          n
# 10829  13821    43     NLD      m    married          y
# 10830  13822  32.0     USA      f    married          n
# 10831  13823  21.0     USA      m     single          n
# 10832  13825    34     USA      f     single          n
# 10833  13828    29     USA      m    married          y
# 10834  13829    28     USA      m        NaN          n
# 10835  13830    50     USA      f   divorced          y
# 10836  13832    34     USA      f    married          y
# 10837  13833  31.0     USA      m    married          y
# 10838  13834    22     USA      m     single          n
# 10839  13835  25.0     USA      m     single          n
# 10840  13836    31     USA      m     single          y
# 10841  13837  22.0     USA      f     single          n
# 10842  13838    38     USA      f    married          y
# 10843  13839    24     USA      f     single          y
#
# [10844 rows x 6 columns]

# %%
hm_new
# Out:
#           hmid    wid reflection_period  \
# 0        27673   2053               24h
# 1        27873   2053               24h
# 2        28073   2053               24h
# 3        33522   2053               24h
# 4        34522   2053               24h
# 5        35522   2053               24h
# 6        40281   2053               24h
# 7        40381   2053               24h
# 8        40481   2053               24h
# 9        27674      2               24h
# 10       27874      2               24h
# 11       28074      2               24h
# 12       29946      2               24h
# 13       30945      2               24h
# 14       31944      2               24h
# 15       32821      2               24h
# 16       33021      2               24h
# 17       33221      2               24h
# 18       33843      2               24h
# 19       34843      2               24h
# 20       35843      2               24h
# 21       36431      2               24h
# 22       36731      2               24h
# 23       37031      2               24h
# 24       37599      2               24h
# 25       38598      2               24h
# 26       39597      2               24h
# 27       40963      2               24h
# 28       41863      2               24h
# 29       42763      2               24h
# ...        ...    ...               ...
# 100505  127721  13677               24h
# 100506  128221  13677               24h
# 100507  128721  13677               24h
# 100508  127724   6895               24h
# 100509  128224   6895               24h
# 100510  128724   6895               24h
# 100511  127727   8689               24h
# 100512  128227   8689               24h
# 100513  128727   8689               24h
# 100514  127733   5798               24h
# 100515  128233   5798               24h
# 100516  128733   5798               24h
# 100517  127740  10983               24h
# 100518  128240  10983               24h
# 100519  128740  10983               24h
# 100520  127743  13605               24h
# 100521  128243  13605               24h
# 100522  128743  13605               24h
# 100523  127747   2974               24h
# 100524  128247   2974               24h
# 100525  128747   2974               24h
# 100526  127748   8880               24h
# 100527  128248   8880               24h
# 100528  128748   8880               24h
# 100529  127751  11402               24h
# 100530  128251  11402               24h
# 100531  128751  11402               24h
# 100532  127759  11050               24h
# 100533  128259  11050               24h
# 100534  128759  11050               24h
#
#                                               original_hm  \
# 0       I went on a successful date with someone I fel...
# 1       I played a new game that was fun and got to en...
# 2       I listened to some music and heard an entire a...
# 3                      Went to see a movie with my friend
# 4                    Played guitar, learning a song on it
# 5                          Talked to my romantic prospect
# 6                 I played a game for about half an hour.
# 7       I discovered another album I hadn't heard by a...
# 8       I talked to the girl I'm dating about some int...
# 9       I was happy when my son got 90% marks in his e...
# 10      I was very happy when my family brings me beau...
# 11      I was happy when I got my new incentives from ...
# 12        When my family cooked my favorite food at night
# 13            When my son got recovery from their disease
# 14      When my mother got finalized stay for transfer...
# 15              When my family plan a abroad tour with me
# 16            When my son realize their emotions and duty
# 17        When my brother got a new job offer from abroad
# 18      I was very happy last 24 hours when I received...
# 19             When my house ready to live with my family
# 20                     When my nephew new born yesterday.
# 21      When my wife got recover from their cough and ...
# 22       When my house ready to possession with my family
# 23      When my friend meet me today with expensive gi...
# 24      When my friend meet to me after many days and ...
# 25      I was very happy when my son playing with whol...
# 26      When my family cooked and buying my favorite c...
# 27      I was very happy last night when I achieved my...
# 28      When my family arrange for trip to abroad with me
# 29         When I shift my new home with my entire family
# ...                                                   ...
# 100505  I got a phone call from my sister, that see is...
# 100506  I attended an engagement in the morning with m...
# 100507  I made some special dishes for lunch, and my n...
# 100508  My son, who is three months old, was able to s...
# 100509  Yesterday was my last day of work before start...
# 100510  I was able to bench press 175 pounds for 3 set...
# 100511  Waking up in the morning, and making myself a ...
# 100512  Watching the clock turn from 5.59 pm to 6.00 p...
# 100513                  Sending my best friend a message.
# 100514  While I was at the store, strawberries were ch...
# 100515  I called an old friend that I have not spoken ...
# 100516  I won in the multiplayer video game I was play...
# 100517  I did a favor for a coworker.  I stayed a bit ...
# 100518  I was able to sell an item on Craigslist, got ...
# 100519  I was able to accomplish one of my goals at wo...
# 100520          Yesterday I took my son to the local zoo.
# 100521  Last night while attending my grandmother's wa...
# 100522  Last night while attending my grandmother's wa...
# 100523  I get to see my best friend after a month, sin...
# 100524  I get to play videogames at home, after a long...
# 100525            I had pizza for dinner and it was great
# 100526  I got on the scales in the morning and I was 5...
# 100527           It's Friday and I get all afternoon off!
# 100528  My husband called me just to tell me he loved me.
# 100529                        Quite dinner with my wife.
# 100530       Was told I was a great employee by my boss.
# 100531                                     Fixed my car.
# 100532  Four year back I lost my job. Now I am living ...
# 100533  Yesterday evening I received a call from unkno...
# 100534  I am fond of seeing cricket match. Yesterday t...
#
#                                                cleaned_hm  modified  \
# 0       I went on a successful date with someone I fel...      True
# 1       I played a new game that was fun and got to en...      True
# 2       I listened to some music and heard an entire a...      True
# 3                      Went to see a movie with my friend      True
# 4                    Played guitar, learning a song on it      True
# 5                          Talked to my romantic prospect      True
# 6                 I played a game for about half an hour.      True
# 7       I discovered another album I hadn't heard by a...      True
# 8       I talked to the girl I'm dating about some int...      True
# 9       I was happy when my son got 90% marks in his e...      True
# 10      I was very happy when my family brings me beau...      True
# 11      I was happy when I got my new incentives from ...      True
# 12        When my family cooked my favorite food at night      True
# 13            When my son got recovery from their disease      True
# 14      When my mother got finalized stay for transfer...      True
# 15              When my family plan a abroad tour with me      True
# 16            When my son realize their emotions and duty      True
# 17        When my brother got a new job offer from abroad      True
# 18      I was very happy last 24 hours when I received...      True
# 19             When my house ready to live with my family      True
# 20                     When my nephew new born yesterday.      True
# 21      When my wife got recover from their cough and ...      True
# 22       When my house ready to possession with my family      True
# 23      When my friend meet me today with expensive gi...      True
# 24      When my friend meet to me after many days and ...      True
# 25      I was very happy when my son playing with whol...      True
# 26      When my family cooked and buying my favorite c...      True
# 27      I was very happy last night when I achieved my...      True
# 28      When my family arrange for trip to abroad with me      True
# 29         When I shift my new home with my entire family      True
# ...                                                   ...       ...
# 100505  I got a phone call from my sister, that see is...      True
# 100506  I attended an engagement in the morning with m...      True
# 100507  I made some special dishes for lunch, and my n...      True
# 100508  My son, who is three months old, was able to s...      True
# 100509  Yesterday was my last day of work before start...      True
# 100510  I was able to bench press 175 pounds for 3 set...      True
# 100511  Waking up in the morning, and making myself a ...      True
# 100512  Watching the clock turn from 5.59 pm to 6.00 p...      True
# 100513                  Sending my best friend a message.      True
# 100514  While I was at the store, strawberries were ch...      True
# 100515  I called an old friend that I have not spoken ...      True
# 100516  I won in the multiplayer video game I was play...      True
# 100517  I did a favor for a coworker.  I stayed a bit ...      True
# 100518  I was able to sell an item on Craigslist, got ...      True
# 100519  I was able to accomplish one of my goals at wo...      True
# 100520          Yesterday I took my son to the local zoo.      True
# 100521  Last night while attending my grandmother's wa...      True
# 100522  Last night while attending my grandmother's wa...      True
# 100523  I get to see my best friend after a month, sin...      True
# 100524  I get to play videogames at home, after a long...      True
# 100525            I had pizza for dinner and it was great      True
# 100526  I got on the scales in the morning and I was 5...      True
# 100527           It's Friday and I get all afternoon off!      True
# 100528  My husband called me just to tell me he loved me.      True
# 100529                        Quite dinner with my wife.       True
# 100530       Was told I was a great employee by my boss.       True
# 100531                                     Fixed my car.       True
# 100532  Four year back I lost my job. Now I am living ...      True
# 100533  Yesterday evening I received a call from unkno...      True
# 100534  I am fond of seeing cricket match. Yesterday t...      True
#
#         num_sentence ground_truth_category predicted_category   age country  \
# 0                  1                   NaN          affection    35     USA
# 1                  1                   NaN            leisure    35     USA
# 2                  1                   NaN            leisure    35     USA
# 3                  1                   NaN            bonding    35     USA
# 4                  1                   NaN            leisure    35     USA
# 5                  1                   NaN          affection    35     USA
# 6                  1               leisure            leisure    35     USA
# 7                  1                   NaN        achievement    35     USA
# 8                  1                   NaN          affection    35     USA
# 9                  1                   NaN          affection  29.0     IND
# 10                 1                   NaN          affection  29.0     IND
# 11                 1                   NaN        achievement  29.0     IND
# 12                 1                   NaN          affection  29.0     IND
# 13                 1                   NaN          affection  29.0     IND
# 14                 1                   NaN          affection  29.0     IND
# 15                 1             affection          affection  29.0     IND
# 16                 1                   NaN          affection  29.0     IND
# 17                 1                   NaN          affection  29.0     IND
# 18                 1                   NaN        achievement  29.0     IND
# 19                 1             affection          affection  29.0     IND
# 20                 1                   NaN          affection  29.0     IND
# 21                 1                   NaN          affection  29.0     IND
# 22                 1                   NaN          affection  29.0     IND
# 23                 1               bonding            bonding  29.0     IND
# 24                 1                   NaN            bonding  29.0     IND
# 25                 1             affection          affection  29.0     IND
# 26                 1                   NaN          affection  29.0     IND
# 27                 1                   NaN          affection  29.0     IND
# 28                 1                   NaN          affection  29.0     IND
# 29                 1                   NaN          affection  29.0     IND
# ...              ...                   ...                ...   ...     ...
# 100505             1                   NaN          affection    64     IND
# 100506             2                   NaN          affection    64     IND
# 100507             1                   NaN          affection    64     IND
# 100508             1                   NaN          affection    34     USA
# 100509             1                   NaN        achievement    34     USA
# 100510             1                   NaN        achievement    34     USA
# 100511             1                   NaN   enjoy_the_moment    24     USA
# 100512             1                   NaN            leisure    24     USA
# 100513             1                   NaN            bonding    24     USA
# 100514             1                   NaN        achievement    26     USA
# 100515             1                   NaN            bonding    26     USA
# 100516             1                   NaN            leisure    26     USA
# 100517             2                   NaN        achievement    32     USA
# 100518             1                   NaN        achievement    32     USA
# 100519             1                   NaN        achievement    32     USA
# 100520             1                   NaN          affection    36     USA
# 100521             1                   NaN          affection    36     USA
# 100522             1                   NaN            bonding    36     USA
# 100523             1                   NaN            bonding    24     MEX
# 100524             1                   NaN            leisure    24     MEX
# 100525             1                   NaN   enjoy_the_moment    24     MEX
# 100526             1           achievement        achievement    58     USA
# 100527             1                   NaN        achievement    58     USA
# 100528             1                   NaN          affection    58     USA
# 100529             1             affection          affection    32     USA
# 100530             1                   NaN        achievement    32     USA
# 100531             1                   NaN        achievement    32     USA
# 100532             6                   NaN        achievement    65     IND
# 100533             7               bonding            bonding    65     IND
# 100534             6                   NaN   enjoy_the_moment    65     IND
#
#        gender  marital parenthood
# 0           m   single          n
# 1           m   single          n
# 2           m   single          n
# 3           m   single          n
# 4           m   single          n
# 5           m   single          n
# 6           m   single          n
# 7           m   single          n
# 8           m   single          n
# 9           m  married          y
# 10          m  married          y
# 11          m  married          y
# 12          m  married          y
# 13          m  married          y
# 14          m  married          y
# 15          m  married          y
# 16          m  married          y
# 17          m  married          y
# 18          m  married          y
# 19          m  married          y
# 20          m  married          y
# 21          m  married          y
# 22          m  married          y
# 23          m  married          y
# 24          m  married          y
# 25          m  married          y
# 26          m  married          y
# 27          m  married          y
# 28          m  married          y
# 29          m  married          y
# ...       ...      ...        ...
# 100505      m  married          y
# 100506      m  married          y
# 100507      m  married          y
# 100508      m  married          y
# 100509      m  married          y
# 100510      m  married          y
# 100511      f   single          n
# 100512      f   single          n
# 100513      f   single          n
# 100514      m   single          n
# 100515      m   single          n
# 100516      m   single          n
# 100517      m   single          n
# 100518      m   single          n
# 100519      m   single          n
# 100520      f  married          y
# 100521      f  married          y
# 100522      f  married          y
# 100523      m   single          n
# 100524      m   single          n
# 100525      m   single          n
# 100526      f  married          n
# 100527      f  married          n
# 100528      f  married          n
# 100529      m  married          n
# 100530      m  married          n
# 100531      m  married          n
# 100532      m  married          y
# 100533      m  married          y
# 100534      m  married          y
#
# [100535 rows x 14 columns]

# %%
# Drop features
hm_new.drop('original_hm', axis=1, inplace=True)

# %%
# Check if its dropped
hm_new.head()
# Out:
#     hmid   wid reflection_period  \
# 0  27673  2053               24h
# 1  27873  2053               24h
# 2  28073  2053               24h
# 3  33522  2053               24h
# 4  34522  2053               24h
#
#                                           cleaned_hm  modified  num_sentence  \
# 0  I went on a successful date with someone I fel...      True             1
# 1  I played a new game that was fun and got to en...      True             1
# 2  I listened to some music and heard an entire a...      True             1
# 3                 Went to see a movie with my friend      True             1
# 4               Played guitar, learning a song on it      True             1
#
#   ground_truth_category predicted_category age country gender marital  \
# 0                   NaN          affection  35     USA      m  single
# 1                   NaN            leisure  35     USA      m  single
# 2                   NaN            leisure  35     USA      m  single
# 3                   NaN            bonding  35     USA      m  single
# 4                   NaN            leisure  35     USA      m  single
#
#   parenthood
# 0          n
# 1          n
# 2          n
# 3          n
# 4          n

# %%
# Drop multiple features at once in a list
hm_new.drop(['cleaned_hm','modified','num_sentence','ground_truth_category'], axis=1, inplace=True)

# %%
hm_new
# Out:
#           hmid    wid reflection_period predicted_category   age country  \
# 0        27673   2053               24h          affection    35     USA
# 1        27873   2053               24h            leisure    35     USA
# 2        28073   2053               24h            leisure    35     USA
# 3        33522   2053               24h            bonding    35     USA
# 4        34522   2053               24h            leisure    35     USA
# 5        35522   2053               24h          affection    35     USA
# 6        40281   2053               24h            leisure    35     USA
# 7        40381   2053               24h        achievement    35     USA
# 8        40481   2053               24h          affection    35     USA
# 9        27674      2               24h          affection  29.0     IND
# 10       27874      2               24h          affection  29.0     IND
# 11       28074      2               24h        achievement  29.0     IND
# 12       29946      2               24h          affection  29.0     IND
# 13       30945      2               24h          affection  29.0     IND
# 14       31944      2               24h          affection  29.0     IND
# 15       32821      2               24h          affection  29.0     IND
# 16       33021      2               24h          affection  29.0     IND
# 17       33221      2               24h          affection  29.0     IND
# 18       33843      2               24h        achievement  29.0     IND
# 19       34843      2               24h          affection  29.0     IND
# 20       35843      2               24h          affection  29.0     IND
# 21       36431      2               24h          affection  29.0     IND
# 22       36731      2               24h          affection  29.0     IND
# 23       37031      2               24h            bonding  29.0     IND
# 24       37599      2               24h            bonding  29.0     IND
# 25       38598      2               24h          affection  29.0     IND
# 26       39597      2               24h          affection  29.0     IND
# 27       40963      2               24h          affection  29.0     IND
# 28       41863      2               24h          affection  29.0     IND
# 29       42763      2               24h          affection  29.0     IND
# ...        ...    ...               ...                ...   ...     ...
# 100505  127721  13677               24h          affection    64     IND
# 100506  128221  13677               24h          affection    64     IND
# 100507  128721  13677               24h          affection    64     IND
# 100508  127724   6895               24h          affection    34     USA
# 100509  128224   6895               24h        achievement    34     USA
# 100510  128724   6895               24h        achievement    34     USA
# 100511  127727   8689               24h   enjoy_the_moment    24     USA
# 100512  128227   8689               24h            leisure    24     USA
# 100513  128727   8689               24h            bonding    24     USA
# 100514  127733   5798               24h        achievement    26     USA
# 100515  128233   5798               24h            bonding    26     USA
# 100516  128733   5798               24h            leisure    26     USA
# 100517  127740  10983               24h        achievement    32     USA
# 100518  128240  10983               24h        achievement    32     USA
# 100519  128740  10983               24h        achievement    32     USA
# 100520  127743  13605               24h          affection    36     USA
# 100521  128243  13605               24h          affection    36     USA
# 100522  128743  13605               24h            bonding    36     USA
# 100523  127747   2974               24h            bonding    24     MEX
# 100524  128247   2974               24h            leisure    24     MEX
# 100525  128747   2974               24h   enjoy_the_moment    24     MEX
# 100526  127748   8880               24h        achievement    58     USA
# 100527  128248   8880               24h        achievement    58     USA
# 100528  128748   8880               24h          affection    58     USA
# 100529  127751  11402               24h          affection    32     USA
# 100530  128251  11402               24h        achievement    32     USA
# 100531  128751  11402               24h        achievement    32     USA
# 100532  127759  11050               24h        achievement    65     IND
# 100533  128259  11050               24h            bonding    65     IND
# 100534  128759  11050               24h   enjoy_the_moment    65     IND
#
#        gender  marital parenthood
# 0           m   single          n
# 1           m   single          n
# 2           m   single          n
# 3           m   single          n
# 4           m   single          n
# 5           m   single          n
# 6           m   single          n
# 7           m   single          n
# 8           m   single          n
# 9           m  married          y
# 10          m  married          y
# 11          m  married          y
# 12          m  married          y
# 13          m  married          y
# 14          m  married          y
# 15          m  married          y
# 16          m  married          y
# 17          m  married          y
# 18          m  married          y
# 19          m  married          y
# 20          m  married          y
# 21          m  married          y
# 22          m  married          y
# 23          m  married          y
# 24          m  married          y
# 25          m  married          y
# 26          m  married          y
# 27          m  married          y
# 28          m  married          y
# 29          m  married          y
# ...       ...      ...        ...
# 100505      m  married          y
# 100506      m  married          y
# 100507      m  married          y
# 100508      m  married          y
# 100509      m  married          y
# 100510      m  married          y
# 100511      f   single          n
# 100512      f   single          n
# 100513      f   single          n
# 100514      m   single          n
# 100515      m   single          n
# 100516      m   single          n
# 100517      m   single          n
# 100518      m   single          n
# 100519      m   single          n
# 100520      f  married          y
# 100521      f  married          y
# 100522      f  married          y
# 100523      m   single          n
# 100524      m   single          n
# 100525      m   single          n
# 100526      f  married          n
# 100527      f  married          n
# 100528      f  married          n
# 100529      m  married          n
# 100530      m  married          n
# 100531      m  married          n
# 100532      m  married          y
# 100533      m  married          y
# 100534      m  married          y
#
# [100535 rows x 9 columns]
